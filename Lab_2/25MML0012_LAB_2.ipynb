# %% [markdown]
# # temp comment
#
# basically in this dataset ie: nltk(names), there are male and female names
#
# here we append male, next to every name in malename.txt, do the same for females
#
#
# after all this we sent the last letter of the names and the gender label, to train the naivebayesclassifier
#
# then we can use naive bayes to classify the test set or names taken as input

# %%
import nltk
import random

nltk.download('names')
# Out:
# [nltk_data] Downloading package names to
# [nltk_data]     C:\Users\batch1\AppData\Roaming\nltk_data...
# [nltk_data]   Package names is already up-to-date!
# True

# %%
def gender_features(word):
    return {'last_letter':word[-1]}

# %%
from nltk.corpus import names
names.words()
print(len(names.words()))
# Out:
# 7944

# %%
labeled_names = ([(name, 'male') for name in names.words('male.txt')] + [(name, 'female') for name in names.words('female.txt')])

# %%
random.shuffle(labeled_names)

featuresets = [(gender_features(n), gender) for (n, gender) in labeled_names]

train_set, test_set = featuresets[0:5000], featuresets[-2000:0]

classifier = nltk.NaiveBayesClassifier.train(train_set)

classifier.classify(gender_features('David'))
classifier.classify(gender_features('Yann Lecun'))

print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.759

# %%
print(len(train_set))
print(len(test_set))
# Out:
# 5000
# 2000

# %%
import pandas as pd

df = pd.read_csv("logs_dataset.csv")

df.head()
